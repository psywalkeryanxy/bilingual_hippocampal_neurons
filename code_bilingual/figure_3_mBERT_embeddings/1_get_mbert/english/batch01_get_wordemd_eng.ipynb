# %% [markdown]
# #### main function

# %%
import numpy as np
import pandas as pd
import torch
from tqdm import tqdm
from transformers import AutoModel, AutoTokenizer
import os
import glob

torch.set_grad_enabled(False)


def extract_mbert_features_paper_method(
    podcast_files: list[str] = None,
    modelname: str = "bert-base-multilingual-cased",
    model_alias: str = "mbert",
    device: str = "cpu",
    output_dir: str = "mbert_features",
):
    """
    extract mBERT features using the exact method from the paper. hasson group, 2025, bilingual, fMRI, story, LPP
    context = up to 509 tokens immediately before current sentence.
    """
    
    
    podcast_files = sorted(glob.glob("sentences_with_*_timing.csv"))

    
    # load tokenizer and model
    tokenizer = AutoTokenizer.from_pretrained(modelname)
    model = AutoModel.from_pretrained(modelname, output_hidden_states=True)
    
    
    model = model.eval()
    model = model.to(device)
    
    cls_token_id = tokenizer.cls_token_id
    sep_token_id = tokenizer.sep_token_id
    
    # process each podcast file, show progress
    for podcast_file in tqdm(podcast_files, desc="get the podcast files"):
        podcast_num = podcast_file.split('_')[-2]
        
        # read sentence data
        sentence_df = pd.read_csv(podcast_file)
        print(f"\nProcessing Podcast {podcast_num}: {len(sentence_df)} sentences")
        
        # create output directory
        output_path = os.path.join(output_dir, model_alias, f"podcast_{podcast_num}")
        os.makedirs(output_path, exist_ok=True)
        
        # first, tokenize all sentences to create a %flat% token list
        all_tokens = []
        sentence_boundaries = []  # (start_idx, end_idx) for each sentence
        
        for idx, row in sentence_df.iterrows():
            start_idx = len(all_tokens)
            
            # Tokenize sentence
            token_ids = tokenizer.encode(row['text'], add_special_tokens=False)######!!!!!, no CLS, SEP
            tokens = tokenizer.convert_ids_to_tokens(token_ids)
            
            # Add to flat list
            for token_id, token in zip(token_ids, tokens):
                all_tokens.append({
                    'token_id': token_id,
                    'token': token,
                    'sentence_id': row['sentence_id'],
                    'sentence_idx': idx
                })
            
            end_idx = len(all_tokens)
            sentence_boundaries.append((start_idx, end_idx))
        
        # convert to dataframe
        token_df = pd.DataFrame(all_tokens)
        token_df['token_idx'] = range(len(token_df))
        
        # extract embeddings for each sentence with proper context
        all_embeddings = []
        
        for sent_idx, (start_idx, end_idx) in enumerate(tqdm(sentence_boundaries, 
                                                             desc=f"extracting embeddings", 
                                                             leave=False)):
            n_sentence_tokens = end_idx - start_idx
            n_context_tokens = 509 - n_sentence_tokens  # 512 - 3 special tokens
            
            # get context tokens (exactly like the paper)
            # calculates how many tokens are in the sentence and how many context tokens can fit 
            #(BERT has a 512 token limit, minus 3 special tokens).
            context_start_idx = max(0, start_idx - n_context_tokens)
            context_tokens = token_df.iloc[context_start_idx:start_idx]['token_id'].tolist()
            sentence_tokens = token_df.iloc[start_idx:end_idx]['token_id'].tolist()
            
            # construct input: [CLS] context [SEP] sentence [SEP]
            input_ids = (
                [cls_token_id] +
                context_tokens +
                [sep_token_id] +
                sentence_tokens +
                [sep_token_id]
            )
            
            # convert to tensor
            example = torch.tensor([input_ids]).to(device)
            
            if example.shape[-1] > 512:
                print(f"Error: Sentence {sent_idx} exceeds 512 tokens!")
                exit(1)  # Match paper behavior
            
            # get model outputs
            outputs = model(input_ids=example)
            
            # Extract embeddings for sentence tokens only (like the paper)
            sentence_states = [
                state[:, -len(sentence_tokens) - 1 : -1, :]
                for state in outputs["hidden_states"]
            ]
            hidden_states = torch.vstack(sentence_states)
            all_embeddings.append(hidden_states.numpy(force=True))
        
        # concatenate all embeddings
        embeddings = np.concatenate(all_embeddings, axis=1)
        
        # save it
        embeddings_file = os.path.join(output_path, 'embeddings.npy')
        np.save(embeddings_file, embeddings)
        print(f"Saved embeddings: {embeddings_file} - Shape: {embeddings.shape}")
        
        # also, save the tokens, plz
        token_df.to_csv(os.path.join(output_path, 'tokens.csv'), index=False)

# %% [markdown]
# #### load podcast 1 .. file

# %%
# check for GPU availability, but ussually use the cpu
device = "cpu"
    
# get features
extract_mbert_features_paper_method(
        podcast_files=None,  #will auto-detect sentences_with_*_timing.csv
        modelname="bert-base-multilingual-cased",
        model_alias="mbert",
        device=device,
        output_dir="mbert_features"
    )
# Out:
# get the podcast files:   0%|                              | 0/1 [00:00<?, ?it/s]
# Processing Podcast 1: 296 sentences
# extracting embeddings:   0%|                            | 0/296 [00:00<?, ?it/s]
# extracting embeddings:   0%|                    | 1/296 [00:00<02:49,  1.74it/s]
# extracting embeddings:   2%|▎                   | 5/296 [00:00<00:32,  8.90it/s]
# extracting embeddings:   3%|▌                   | 8/296 [00:00<00:22, 12.67it/s]
# extracting embeddings:   4%|▋                  | 11/296 [00:00<00:19, 14.71it/s]
# extracting embeddings:   5%|▉                  | 14/296 [00:01<00:18, 15.05it/s]
# extracting embeddings:   5%|█                  | 16/296 [00:01<00:18, 14.86it/s]
# extracting embeddings:   6%|█▏                 | 18/296 [00:01<00:19, 14.31it/s]
# extracting embeddings:   7%|█▎                 | 20/296 [00:01<00:19, 14.01it/s]
# extracting embeddings:   7%|█▍                 | 22/296 [00:01<00:19, 13.82it/s]
# extracting embeddings:   8%|█▌                 | 24/296 [00:01<00:19, 13.62it/s]
# extracting embeddings:   9%|█▋                 | 26/296 [00:02<00:19, 13.64it/s]
# extracting embeddings:   9%|█▊                 | 28/296 [00:02<00:19, 13.71it/s]
# extracting embeddings:  10%|█▉                 | 30/296 [00:02<00:19, 13.80it/s]
# extracting embeddings:  11%|██                 | 32/296 [00:02<00:19, 13.25it/s]
# extracting embeddings:  11%|██▏                | 34/296 [00:02<00:20, 13.04it/s]
# extracting embeddings:  12%|██▎                | 36/296 [00:02<00:19, 13.10it/s]
# extracting embeddings:  13%|██▍                | 38/296 [00:02<00:19, 13.42it/s]
# extracting embeddings:  14%|██▌                | 40/296 [00:03<00:18, 13.48it/s]
# extracting embeddings:  14%|██▋                | 42/296 [00:03<00:18, 13.55it/s]
# extracting embeddings:  15%|██▊                | 44/296 [00:03<00:19, 12.96it/s]
# extracting embeddings:  16%|██▉                | 46/296 [00:03<00:18, 13.35it/s]
# extracting embeddings:  16%|███                | 48/296 [00:03<00:18, 13.57it/s]
# extracting embeddings:  17%|███▏               | 50/296 [00:03<00:18, 13.60it/s]
# extracting embeddings:  68%|████████████▏     | 200/296 [00:14<00:06, 14.77it/s]
# extracting embeddings:  68%|████████████▎     | 202/296 [00:14<00:06, 14.75it/s]
# extracting embeddings:  69%|████████████▍     | 204/296 [00:14<00:06, 14.76it/s]
# extracting embeddings:  70%|████████████▌     | 206/296 [00:14<00:06, 14.68it/s]
# extracting embeddings:  70%|████████████▋     | 208/296 [00:14<00:06, 14.66it/s]
# extracting embeddings:  71%|████████████▊     | 210/296 [00:14<00:06, 14.24it/s]
# extracting embeddings:  72%|████████████▉     | 212/296 [00:15<00:05, 14.39it/s]
# extracting embeddings:  72%|█████████████     | 214/296 [00:15<00:05, 14.50it/s]
# extracting embeddings:  73%|█████████████▏    | 216/296 [00:15<00:05, 14.65it/s]
# extracting embeddings:  74%|█████████████▎    | 218/296 [00:15<00:05, 14.76it/s]
# extracting embeddings:  74%|█████████████▍    | 220/296 [00:15<00:05, 14.79it/s]
# extracting embeddings:  75%|█████████████▌    | 222/296 [00:15<00:05, 14.76it/s]
# extracting embeddings:  76%|█████████████▌    | 224/296 [00:15<00:04, 14.74it/s]
# extracting embeddings:  76%|█████████████▋    | 226/296 [00:16<00:04, 14.86it/s]
# extracting embeddings:  77%|█████████████▊    | 228/296 [00:16<00:04, 14.84it/s]
# extracting embeddings:  78%|█████████████▉    | 230/296 [00:16<00:04, 14.94it/s]
# extracting embeddings:  78%|██████████████    | 232/296 [00:16<00:04, 14.87it/s]
# extracting embeddings:  79%|██████████████▏   | 234/296 [00:16<00:04, 14.97it/s]
# extracting embeddings:  80%|██████████████▎   | 236/296 [00:16<00:04, 14.97it/s]
# extracting embeddings:  80%|██████████████▍   | 238/296 [00:16<00:03, 14.94it/s]
# extracting embeddings:  81%|██████████████▌   | 240/296 [00:16<00:03, 14.96it/s]
# extracting embeddings:  82%|██████████████▋   | 242/296 [00:17<00:03, 14.86it/s]
# extracting embeddings:  82%|██████████████▊   | 244/296 [00:17<00:03, 14.91it/s]
# extracting embeddings:  83%|██████████████▉   | 246/296 [00:17<00:03, 14.94it/s]
# extracting embeddings:  84%|███████████████   | 248/296 [00:17<00:03, 14.93it/s]
# extracting embeddings:  84%|███████████████▏  | 250/296 [00:17<00:03, 14.99it/s]
# extracting embeddings:  85%|███████████████▎  | 252/296 [00:17<00:02, 15.04it/s]
# extracting embeddings:  86%|███████████████▍  | 254/296 [00:17<00:02, 15.13it/s]
# extracting embeddings:  86%|███████████████▌  | 256/296 [00:18<00:02, 15.13it/s]
# extracting embeddings:  87%|███████████████▋  | 258/296 [00:18<00:02, 15.08it/s]
# extracting embeddings:  88%|███████████████▊  | 260/296 [00:18<00:02, 15.01it/s]
# extracting embeddings:  89%|███████████████▉  | 262/296 [00:18<00:02, 15.10it/s]
# extracting embeddings:  89%|████████████████  | 264/296 [00:18<00:02, 15.07it/s]
# extracting embeddings:  90%|████████████████▏ | 266/296 [00:18<00:01, 15.08it/s]
# extracting embeddings:  91%|████████████████▎ | 268/296 [00:18<00:01, 15.03it/s]
# extracting embeddings:  91%|████████████████▍ | 270/296 [00:18<00:01, 15.09it/s]
# extracting embeddings:  92%|████████████████▌ | 272/296 [00:19<00:01, 15.08it/s]
# extracting embeddings:  93%|████████████████▋ | 274/296 [00:19<00:01, 15.08it/s]
# extracting embeddings:  93%|████████████████▊ | 276/296 [00:19<00:01, 15.07it/s]
# extracting embeddings:  94%|████████████████▉ | 278/296 [00:19<00:01, 15.14it/s]
# extracting embeddings:  95%|█████████████████ | 280/296 [00:19<00:01, 15.11it/s]
# extracting embeddings:  95%|█████████████████▏| 282/296 [00:19<00:00, 15.11it/s]
# extracting embeddings:  96%|█████████████████▎| 284/296 [00:19<00:00, 15.01it/s]
# extracting embeddings:  97%|█████████████████▍| 286/296 [00:20<00:00, 14.93it/s]
# extracting embeddings:  97%|█████████████████▌| 288/296 [00:20<00:00, 15.04it/s]
# extracting embeddings:  98%|█████████████████▋| 290/296 [00:20<00:00, 15.02it/s]
# extracting embeddings:  99%|█████████████████▊| 292/296 [00:20<00:00, 14.97it/s]
# extracting embeddings:  99%|█████████████████▉| 294/296 [00:20<00:00, 14.97it/s]
# extracting embeddings: 100%|██████████████████| 296/296 [00:20<00:00, 15.00it/s]
# get the podcast files: 100%|██████████████████████| 1/1 [00:20<00:00, 20.76s/it]
# Saved embeddings: mbert_features/mbert/podcast_1/embeddings.npy - Shape: (13, 6361, 768)

# %% [markdown]
# #### check the file

# %%
import numpy as np
import pandas as pd

# load the files
podcast_num = 1
base_path = f"mbert_features/mbert/podcast_{podcast_num}"

embeddings = np.load(f"{base_path}/embeddings.npy")
embeddings.shape
# Out:
# (13, 6361, 768)

# %%
import numpy as np
import pandas as pd

# Load files
podcast_num = 1
base_path = f"mbert_features/mbert/podcast_{podcast_num}"

# Load data
embeddings = np.load(f"{base_path}/embeddings.npy")  # Shape: (13, 2007, 768)
tokens_df = pd.read_csv(f"{base_path}/tokens.csv")
sentence_df = pd.read_csv(f"sentences_with_{podcast_num}_timing.csv")  # Original sentences

print(f"Embeddings shape: {embeddings.shape}")
print(f"Tokens: {len(tokens_df)} tokens")
print(f"Sentences: {len(sentence_df)} sentences")


#  accurate mapping using sentence text
def create_word_mapping_accurate():
    """Create more accurate word mapping by aligning with original sentence"""
    from transformers import AutoTokenizer
    tokenizer = AutoTokenizer.from_pretrained("bert-base-multilingual-cased")
    
    word_mappings = []
    
    for _, sent_row in sentence_df.iterrows():
        sentence_id = sent_row['sentence_id']
        sentence_text = sent_row['text']
        first_word_idx = sent_row['first_word_idx']
        
        # Get sentence tokens from tokens_df
        sentence_tokens = tokens_df[tokens_df['sentence_id'] == sentence_id].sort_values('token_idx')
        
        if len(sentence_tokens) == 0:
            continue
            
        # Split sentence into words
        words = sentence_text.split()
        
        # Get token spans for each word
        current_token_pos = 0
        
        for word_pos, word in enumerate(words):
            word_idx = first_word_idx + word_pos
            
            # Tokenize this word
            word_tokens = tokenizer.tokenize(word)
            n_word_tokens = len(word_tokens)
            
            # Map tokens to this word
            for i in range(n_word_tokens):
                if current_token_pos < len(sentence_tokens):
                    token_row = sentence_tokens.iloc[current_token_pos]
                    
                    word_mappings.append({
                        'word_idx': word_idx,
                        'token_idx': token_row['token_idx'],
                        'token': token_row['token'],
                        'token_id': token_row['token_id'],
                        'sentence_id': sentence_id
                    })
                    
                    current_token_pos += 1
    
    return pd.DataFrame(word_mappings)

######### 

word_mapping_df = create_word_mapping_accurate()

# Save the mapping
mapping_file = f"{base_path}/word_token_mapping.csv"
word_mapping_df.to_csv(mapping_file, index=False)
print(f"Saved word mapping to: {mapping_file}")

# Display statistics
print(f"\nMapping statistics:")
print(f"Total mappings: {len(word_mapping_df)}")
print(f"Unique words: {word_mapping_df['word_idx'].nunique()}")
print(f"Tokens per word: {len(word_mapping_df) / word_mapping_df['word_idx'].nunique():.2f}")

# Show example mappings
print("\nExample word mappings:")
example_word = word_mapping_df['word_idx'].iloc[10]
example_mappings = word_mapping_df[word_mapping_df['word_idx'] == example_word]
print(f"Word {example_word}:")
print(example_mappings[['token_idx', 'token', 'token_id']])
# Out:
# Embeddings shape: (13, 6361, 768)
# Tokens: 6361 tokens
# Sentences: 296 sentences
# Saved word mapping to: mbert_features/mbert/podcast_1/word_token_mapping.csv
#
# Mapping statistics:
# Total mappings: 6361
# Unique words: 4855
# Tokens per word: 1.31
#
# Example word mappings:
# Word 8:
#     token_idx token  token_id
# 10         10  holy     95652

# %%
import numpy as np
import pandas as pd
import string

# Define punctuation to exclude
PUNCTUATION = set(string.punctuation + '–—""''')  # Include various dash and quote types

def is_punctuation_token(token):
    """Check if a token is punctuation"""
    # Remove ## prefix for subword tokens
    clean_token = token.replace('##', '')
    # Check if it's only punctuation
    return all(c in PUNCTUATION for c in clean_token)

def get_word_embeddings_all_layers(exclude_punctuation=True):
    """Extract embeddings for all words across all layers"""
    all_results = {}
    
    # First, let's check for any issues in the mapping
    print(f"\nChecking word_mapping_df for issues...")
    print(f"Null tokens: {word_mapping_df['token'].isnull().sum()}")
    print(f"Total unique words: {word_mapping_df['word_idx'].nunique()}")
    
    # Process each layer
    for layer in range(embeddings.shape[0]):
        print(f"\nProcessing layer {layer}...")
        layer_results = []
        
        for word_idx in sorted(word_mapping_df['word_idx'].unique()):
            # Get tokens for this word
            word_tokens = word_mapping_df[word_mapping_df['word_idx'] == word_idx]
            
            # Reconstruct word from tokens
            tokens = word_tokens['token'].values
            tokens_str = [str(t) if pd.notna(t) else '' for t in tokens]
            word_text = ''.join(tokens_str).replace('##', '')
            
            # Skip if word is only punctuation and exclude_punctuation is True
            if exclude_punctuation and all(c in PUNCTUATION for c in word_text):
                continue
            
            # Skip if no valid tokens
            token_indices = word_tokens['token_idx'].values
            if len(token_indices) == 0:
                continue
            
            # Filter out punctuation tokens if needed
            if exclude_punctuation:
                # Keep only non-punctuation tokens
                non_punct_mask = [not is_punctuation_token(str(t)) for t in tokens]
                if any(non_punct_mask):
                    token_indices = token_indices[non_punct_mask]
                else:
                    # All tokens are punctuation, skip this word
                    continue
            
            # Get embeddings
            token_embeddings = embeddings[layer, token_indices, :]
            word_embedding = token_embeddings.mean(axis=0)
            
            row = {
                'word_idx': word_idx,
                'word': word_text,
                'n_tokens': len(token_indices),  # Number of tokens used (after filtering)
                'sentence_id': word_tokens['sentence_id'].iloc[0]
            }
            
            # Add embedding dimensions
            for i in range(768):
                row[f'dim_{i}'] = word_embedding[i]
                
            layer_results.append(row)
        
        all_results[layer] = pd.DataFrame(layer_results)
        print(f"Layer {layer}: Extracted {len(layer_results)} words (excluded punctuation: {exclude_punctuation})")
    
    return all_results

# Extract embeddings for all layers

all_layer_embeddings = get_word_embeddings_all_layers(exclude_punctuation=True)

# Save each layer's embeddings
for layer, df in all_layer_embeddings.items():
    output_file = f"{base_path}/word_embeddings_layer{layer}.csv"
    df.to_csv(output_file, index=False)
    print(f"Saved layer {layer} embeddings to: {output_file}")
# Out:
# Checking word_mapping_df for issues...
# Null tokens: 0
# Total unique words: 4855
#
# Processing layer 0...
# Layer 0: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 1...
# Layer 1: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 2...
# Layer 2: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 3...
# Layer 3: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 4...
# Layer 4: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 5...
# Layer 5: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 6...
# Layer 6: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 7...
# Layer 7: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 8...
# Layer 8: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 9...
# Layer 9: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 10...
# Layer 10: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 11...
# Layer 11: Extracted 4855 words (excluded punctuation: True)
#
# Processing layer 12...
# Layer 12: Extracted 4855 words (excluded punctuation: True)
# Saved layer 0 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer0.csv
# Saved layer 1 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer1.csv
# Saved layer 2 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer2.csv
# Saved layer 3 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer3.csv
# Saved layer 4 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer4.csv
# Saved layer 5 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer5.csv
# Saved layer 6 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer6.csv
# Saved layer 7 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer7.csv
# Saved layer 8 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer8.csv
# Saved layer 9 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer9.csv
# Saved layer 10 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer10.csv
# Saved layer 11 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer11.csv
# Saved layer 12 embeddings to: mbert_features/mbert/podcast_1/word_embeddings_layer12.csv
